# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/occurrence_ecoregions.csv")
df.head()
# Out:
#        basisOfRecord   eventDate       eventTime   day  decimalLatitude  \
# 0  HUMAN_OBSERVATION  2024-01-08  09:41:10-05:00   8.0        46.232197
# 1  HUMAN_OBSERVATION         NaN  17:54:00-05:00  24.0        43.022520
# 2  HUMAN_OBSERVATION         NaN  08:50:00-05:00   9.0        42.450188
# 3  HUMAN_OBSERVATION  2024-03-01  17:30:54-05:00   1.0        44.662766
# 4  HUMAN_OBSERVATION  2024-03-14  13:56:54-04:00  14.0        43.083748
#
#    decimalLongitude  coordinateUncertaintyInMeters        order  elevation  \
# 0        -67.793870                           34.0    Hemiptera        NaN
# 1        -77.060684                           15.0  Lepidoptera        NaN
# 2        -71.120190                            6.0   Coleoptera        NaN
# 3        -74.997230                           23.0   Coleoptera        NaN
# 4        -71.976890                            6.0  Lepidoptera        NaN
#
#    hasCoordinate  hasGeospatialIssues speciesKey                 species  \
# ...
